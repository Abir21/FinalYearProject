# %%
# %pip install sklearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline

# %%
refugee = pd.read_csv('1milrefugee_f_dataset.csv', index_col=0)

# %%
df = refugee.copy()

# %%
df['last_occupation'].value_counts()
# Out:
# Construction Worker                               88977
# Mechanic                                          88976
# Farmer                                            88899
# Fisher                                            88696
# Chefs                                             88550
#                                                   ...
# Senior Administrative Assistant                    1466
# Senior Newtwork Engineer                           1457
# Senior Machine Learning Professional               1452
# Junior Software DeveloperJunior Data Scientist     1441
# Senior Software Developer                          1427
# Name: last_occupation, Length: 75, dtype: int64

# %%
df.head()
# Out:
#                                  id                   language  \
# 0  b3e218d26d574d179a9b5a639203a6d8  Native + English + French
# 1  5bcda5b98bdb462d82d122a5bf01dc98  Native + English + French
# 2  928ac2f316bd42e7b429ca325de21d7b                     Native
# 3  43a0bd7fffe24834855d3fa1b808c3b8           Native + English
# 4  12f75c6c8652411985bbe80f0b3d950c                     Native
#
#     education_level            last_occupation predicted_employment_nation  \
# 0       High School               Not employed                      Canada
# 1           Primary        Construction Worker                      France
# 2           Primary                     Farmer                          US
# 3  Associate Degree  Junior Legal Professional                          US
# 4      No Education                     Farmer                      France
#
#     predicted_new_occupation  predicted_new_income  predicted_living_cost  \
# ...

# %%
df = df.drop(['id', 'predicted_new_occupation', 'predicted_new_income', 'predicted_employment_nation', 'predicted_living_cost', 'predicted_tax_rate', 'predicted_tax_ammount', 'discretionary_income', 'would_relying_on', 'predicted_unchr_mandatory_contribution_amount_of_all', 'accepted_refugee_unhcr_contribution_prediction', 'single_family_support_contribution', 'number_of_refugee_family_supported', 'qualified_for_unhcr_mandatory_contribution', 'impact_level', 'mandatory_contribution_range'], axis=1)

# %%
 df=df.loc[[3],['language', 'education_level', 'last_occupation']]

# %%
df.head()
# Out:
#            language   education_level            last_occupation
# 3  Native + English  Associate Degree  Junior Legal Professional

# %%
df.to_csv('example_accept_final_dataset.csv')
